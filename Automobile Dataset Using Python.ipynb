# %% [markdown]
# # What is Exploratory Data Analysis?
# #### Exploratory Data Analysis or EDA is used to take insights from the data. Data Scientists and Analysts try to find different patterns, relations, and anomalies in the data using some statistical graphs and other visualization techniques. Following things are part of EDA :

# %% [markdown]
# Get maximum insights from a data set\
# Uncover underlying structure\
# Extract important variables from the dataset\
# Detect outliers and anomalies(if any)\
# Test underlying assumptions\
# Determine the optimal factor settings

# %% [markdown]
# # Why EDA is important?

# %% [markdown]
# The main purpose of EDA is to detect any errors, outliers as well as to understand different patterns in the data.
# It allows Analysts to understand the data better before making any assumptions.
# The outcomes of EDA helps businesses to know their customers, expand their business and take decisions accordingly

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r'C:\Users\RD\Downloads\archive (4)\Automobile_data.csv')

# %%
df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
cols=['symboling','normalized_losses','make','fuel_type','aspiration','num_of_doors','body_style','drive_wheels_engine','location','wheel_base','length','width','height','curb_weight','engine_type','num_of_cylinders','engine_size','fuel_system','bore','stroke','compression_ratio','horsepower','peak_rpm','city_mpg','highway_mpg','price']

# %%
df.columns=cols

# %%
df.head()
# Out:
#    symboling normalized_losses         make fuel_type aspiration num_of_doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body_style drive_wheels_engine location  wheel_base  ...  engine_size  \
# 0  convertible                 rwd    front        88.6  ...          130
# 1  convertible                 rwd    front        88.6  ...          130
# 2    hatchback                 rwd    front        94.5  ...          152
# 3        sedan                 fwd    front        99.8  ...          109
# 4        sedan                 4wd    front        99.4  ...          136
#
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
list(df)
# Out:
# ['symboling',
#  'normalized_losses',
#  'make',
#  'fuel_type',
#  'aspiration',
#  'num_of_doors',
#  'body_style',
#  'drive_wheels_engine',
#  'location',
#  'wheel_base',
#  'length',
#  'width',
#  'height',
#  'curb_weight',
#  'engine_type',
#  'num_of_cylinders',
#  'engine_size',
#  'fuel_system',
#  'bore',
#  'stroke',
#  'compression_ratio',
#  'horsepower',
#  'peak_rpm',
#  'city_mpg',
#  'highway_mpg',
#  'price']

# %%
df.dtypes
# Out:
# symboling                int64
# normalized_losses       object
# make                    object
# fuel_type               object
# aspiration              object
# num_of_doors            object
# body_style              object
# drive_wheels_engine     object
# location                object
# wheel_base             float64
# length                 float64
# width                  float64
# height                 float64
# curb_weight              int64
# engine_type             object
# num_of_cylinders        object
# engine_size              int64
# fuel_system             object
# bore                    object
# stroke                  object
# compression_ratio      float64
# horsepower              object
# peak_rpm                object
# city_mpg                 int64
# highway_mpg              int64
# price                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            205 non-null    int64
#  1   normalized_losses    205 non-null    object
#  2   make                 205 non-null    object
#  3   fuel_type            205 non-null    object
#  4   aspiration           205 non-null    object
#  5   num_of_doors         205 non-null    object
#  6   body_style           205 non-null    object
#  7   drive_wheels_engine  205 non-null    object
#  8   location             205 non-null    object
#  9   wheel_base           205 non-null    float64
#  10  length               205 non-null    float64
#  11  width                205 non-null    float64
#  12  height               205 non-null    float64
#  13  curb_weight          205 non-null    int64
#  14  engine_type          205 non-null    object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel_base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb_weight  engine_size  compression_ratio    city_mpg  highway_mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe().T
# Out:
#                    count         mean         std     min     25%     50%  \
# symboling          205.0     0.834146    1.245307    -2.0     0.0     1.0
# wheel_base         205.0    98.756585    6.021776    86.6    94.5    97.0
# length             205.0   174.049268   12.337289   141.1   166.3   173.2
# width              205.0    65.907805    2.145204    60.3    64.1    65.5
# height             205.0    53.724878    2.443522    47.8    52.0    54.1
# curb_weight        205.0  2555.565854  520.680204  1488.0  2145.0  2414.0
# engine_size        205.0   126.907317   41.642693    61.0    97.0   120.0
# compression_ratio  205.0    10.142537    3.972040     7.0     8.6     9.0
# city_mpg           205.0    25.219512    6.542142    13.0    19.0    24.0
# highway_mpg        205.0    30.751220    6.886443    16.0    25.0    30.0
#
#                       75%     max
# symboling             2.0     3.0
# wheel_base          102.4   120.9
# length              183.1   208.1
# ...

# %% [markdown]
# # Know data checking and cleaning process

# %%
df['horsepower']
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: object

# %%
#Cleaning Price attribute
price = df['price'].loc[df['price'] != '?']
pmean = price.astype(str).astype(int).mean()
df['price'] = df['price'].replace('?',pmean).astype(int)
df['price'].head()
# Out:
# 0    13495
# 1    16500
# 2    16500
# 3    13950
# 4    17450
# Name: price, dtype: int32

# %%
#Cleaning Horsepower attribute
horsepower = df['horsepower'].loc[df['horsepower'] != '?']
hpmean = horsepower.astype(str).astype(int).mean()
df['horsepower'] = df['horsepower'].replace('?',hpmean).astype(int)
df['horsepower']
# Out:
# 0      111
# 1      111
# 2      154
# 3      102
# 4      115
#       ...
# 200    114
# 201    160
# 202    134
# 203    106
# 204    114
# Name: horsepower, Length: 205, dtype: int32

# %%
#Cleaning the Bore & Stroke data
df = df[df['bore'].notna()]
df = df[df['stroke'].notna()]

# %% [markdown]
# # Visualization

# %%
df["horsepower"].value_counts()
# Out:
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 62      6
# 101     6
# 160     6
# 88      6
# 145     5
# 102     5
# 84      5
# 97      5
# 76      5
# 82      5
# 123     4
# 86      4
# 92      4
# 111     4
# 90      3
# 85      3
# 73      3
# 207     3
# 152     3
# 182     3
# 121     3
# 112     2
# 52      2
# 56      2
# 184     2
# 176     2
# 162     2
# 161     2
# 155     2
# 156     2
# 100     2
# 94      2
# 104     2
# 200     1
# 288     1
# 48      1
# 120     1
# 55      1
# 106     1
# 58      1
# 60      1
# 64      1
# 142     1
# 143     1
# 175     1
# 72      1
# 134     1
# 135     1
# 78      1
# 115     1
# 154     1
# 140     1
# 262     1
# Name: horsepower, dtype: int64

# %%
median_hp = df[df["horsepower"]!="?"]["horsepower"].median()
print(median_hp)
# Out:
# 95.0

# %%
df["num_of_doors"].value_counts()
# Out:
# four    114
# two      89
# ?         2
# Name: num_of_doors, dtype: int64

# %%
df["make"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["fuel_type"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["fuel_type"].value_counts().plot.pie(autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='fuel_type'>

# %%
df[['engine_size','peak_rpm','curb_weight','horsepower','price','highway_mpg']].hist(figsize=(10,8),bins=6,color='g',linewidth='3',edgecolor='k')
plt.tight_layout()
plt.show()

# %%
df['aspiration'].value_counts().plot.pie(figsize=(6,6), autopct='%.2f')
plt.title("Fuel type pie diagram")
plt.ylabel("Number of vehicles")
plt.xlabel("Fuel type")
# Out:
# Text(0.5, 0, 'Fuel type')

# %%
df['drive_wheels_engine'].value_counts().plot(kind='bar',color='#33ddff')
plt.title("drive_wheels_engine chart")
plt.ylabel('Number of vehicles')
plt.xlabel('drive_wheels_engine');

# %%
df["drive_wheels_engine"].value_counts().plot.pie(autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='drive_wheels_engine'>

# %%
df["horsepower"].value_counts().plot.hist(bins=6)
plt.title("Horse Power Graph")
plt.ylabel("Number of vehicles")
plt.xlabel("HP")
# Out:
# Text(0.5, 0, 'HP')

# %%
df["num_of_doors"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["engine_type"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df["engine_size"].value_counts().plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.make.value_counts().nlargest(10).plot(kind='bar', figsize=(15,5), color = '#33ccff')
plt.title("Number of vehicles by make")
plt.ylabel('Number of vehicles')
plt.xlabel('Make')
# Out:
# Text(0.5, 0, 'Make')

# %%
df.symboling.hist(bins=6,color='#33ddef')
plt.title('Insurance risk ratings of vehicles')
plt.ylabel("Number of vehicles")
plt.xlabel("Risk rating")
# Out:
# Text(0.5, 0, 'Risk rating')

# %%
corr = df.corr()

# %%
corr
# Out:
#                    symboling  wheel_base    length     width    height  \
# symboling           1.000000   -0.531954 -0.357612 -0.232919 -0.541038
# wheel_base         -0.531954    1.000000  0.874587  0.795144  0.589435
# length             -0.357612    0.874587  1.000000  0.841118  0.491029
# width              -0.232919    0.795144  0.841118  1.000000  0.279210
# height             -0.541038    0.589435  0.491029  0.279210  1.000000
# curb_weight        -0.227691    0.776386  0.877728  0.867032  0.295572
# engine_size        -0.105790    0.569329  0.683360  0.735433  0.067149
# compression_ratio  -0.178515    0.249786  0.158414  0.181129  0.261214
# horsepower          0.071380    0.351985  0.554408  0.642176 -0.110114
# city_mpg           -0.035823   -0.470414 -0.670909 -0.642704 -0.048640
# highway_mpg         0.034606   -0.544082 -0.704662 -0.677218 -0.107358
# price              -0.082201    0.583168  0.682986  0.728699  0.134388
#
# ...

# %%
plt.figure(figsize=(20,9))
a = sns.heatmap(corr, annot=True, fmt='.2f')

# %%
plt.figure(figsize=(10,10))
plt.scatter(df["engine_size"],df["peak_rpm"])

# %%
g = sns.lmplot("highway_mpg","curb_weight",df,hue= "make",fit_reg=False)
# Out:
# E:\python Data science\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
h = sns.pairplot(df[["city_mpg", "horsepower", "engine_size", "curb_weight","price", "fuel_type"]], hue="fuel_type", diag_kind="hist")

# %% [markdown]
#                                              # END Stay Happy Be Safe
